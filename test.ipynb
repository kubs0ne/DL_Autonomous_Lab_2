# %%
from tensorflow.keras import applications

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
model = applications.ResNet50(weights = 'imagenet', include_top=False, input_shape = (240, 240, 3))
# Out:
# ...
# 94781440/94765736 [==============================] - 28s 0us/step

# %%
model = applications.InceptionV3(weights = 'imagenet', include_top=False, input_shape = (240, 240, 3))
# Out:
# ...
# 87924736/87910968 [==============================] - 39s 0us/step

# %%
for layer in model.layers:
    print(layer)

# %%
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 240, 240, 3  0           []
#                                 )]
#
#  conv2d_188 (Conv2D)            (None, 119, 119, 32  864         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 119, 119, 32  96         ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  activation_188 (Activation)    (None, 119, 119, 32  0           ['batch_normalization_188[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 117, 117, 32  9216        ['activation_188[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 117, 117, 32  96         ['conv2d_189[0][0]']
#  Normalization)                 )
#
# ...
